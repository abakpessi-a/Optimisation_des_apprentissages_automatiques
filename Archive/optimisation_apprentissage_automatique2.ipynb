# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
data=pd.read_csv("student_habits_performance.csv")

# %%
#annalyse descriptive de notre dataset
print(f"dimension de notre dataset: {data.shape}")
print("")
      
print("entete de notre dataset : les 10 prémières lignes :") 
print(data.head(10))  
print("")
      
      
print(f"information générale")
print(data.info())
# Out:
# dimension de notre dataset: (1000, 16)
#
# entete de notre dataset : les 10 prémières lignes :
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
# 5      S1005   24    Male                  7.2                 1.3
# 6      S1006   21  Female                  5.6                 1.5
# 7      S1007   21  Female                  4.3                 1.0
# 8      S1008   23  Female                  4.4                 2.2
# 9      S1009   18  Female                  4.8                 3.1
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
# 5            0.0            No                   82.9          7.4
# 6            1.4           Yes                   85.8          6.5
# 7            2.0           Yes                   77.7          4.6
# 8            1.7            No                  100.0          7.1
# 9            1.3            No                   95.4          7.5
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
# 5         Fair                   1                   Master          Average
# 6         Good                   2                   Master             Poor
# 7         Fair                   0                 Bachelor          Average
# 8         Good                   3                 Bachelor             Good
# 9         Good                   5                 Bachelor             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4
# 5                     4                            No       100.0
# 6                     4                            No        89.8
# 7                     8                            No        72.6
# 8                     1                            No        78.9
# 9                    10                           Yes       100.0
#
# information générale
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   str
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), str(7)
# memory usage: 125.1 KB
# None

# %%
print("vérification des lignes  dupliquées dans notre dataset: ",data.duplicated().sum()," lignes dupliquées")
# Out:
# vérification des lignes  dupliquées dans notre dataset:  0  lignes dupliquées

# %%
#suppression de la colonne student_id  
data=data.drop(columns=["student_id"])

# %%
print("vérification des valeurs manquantes:")
print(data.isnull().sum())
# Out:
# vérification des valeurs manquantes:
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
print("pourcentage des valeurs manquantes par colonne:")
print(data.isnull().mean()*100)
# Out:
# pourcentage des valeurs manquantes par colonne:
# age                              0.0
# gender                           0.0
# study_hours_per_day              0.0
# social_media_hours               0.0
# netflix_hours                    0.0
# part_time_job                    0.0
# attendance_percentage            0.0
# sleep_hours                      0.0
# diet_quality                     0.0
# exercise_frequency               0.0
# parental_education_level         9.1
# internet_quality                 0.0
# mental_health_rating             0.0
# extracurricular_participation    0.0
# exam_score                       0.0
# dtype: float64

# %%
#informaton sur la colonne des valeurs manquantes
data["parental_education_level"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: parental_education_level
# Non-Null Count  Dtype
# --------------  -----
# 909 non-null    str
# dtypes: str(1)
# memory usage: 7.9 KB

# %%
# Vérifons si une colonne de notre dataset est colérée avec les valeurs manquantes
df=data.dropna()
print(f"nouvelle dimension:{df.shape}")

# encodage des variables catégorielles nominales
df=pd.get_dummies(data,columns=["gender"],drop_first=True)
df["part_time_job"]=(data["part_time_job"]=="Yes").astype(int)
df["extracurricular_participation"]=(data["extracurricular_participation"]=="Yes").astype(int)


#encodage des valeurs catégorielle ordinales
diet_map={"Poor": 1,"Fair":1, "Good":2}
p_map={"High School": 1,"Bachelor":2, "Master":3}
internet_map={"Poor": 1,"Average":2, "Good":3}

df["parental_education_level"]=data["parental_education_level"].map(p_map)
df["internet_quality"]=data["internet_quality"].map(internet_map)
df["diet_quality"]=data["diet_quality"].map(diet_map)
# Out:
# nouvelle dimension:(909, 15)

# %%
#matrice de corrélation 
correlation = df.corr()
print(correlation)
# Out:
#                                     age  study_hours_per_day  \
# age                            1.000000             0.003971
# study_hours_per_day            0.003971             1.000000
# social_media_hours            -0.009151             0.020282
# netflix_hours                 -0.001174            -0.031158
# part_time_job                 -0.011680            -0.029133
# attendance_percentage         -0.026055             0.026264
# sleep_hours                    0.037482            -0.027757
# diet_quality                  -0.002006            -0.003565
# exercise_frequency            -0.003836            -0.028701
# parental_education_level       0.027578             0.001925
# internet_quality               0.007799             0.014459
# mental_health_rating          -0.045101            -0.003768
# extracurricular_participation -0.004993            -0.003264
# exam_score                    -0.008907             0.825419
# gender_Male                    0.025562            -0.025634
# gender_Other                   0.015309             0.008814
#
#                                social_media_hours  netflix_hours  \
# age                                     -0.009151      -0.001174
# study_hours_per_day                      0.020282      -0.031158
# social_media_hours                       1.000000       0.011477
# netflix_hours                            0.011477       1.000000
# part_time_job                            0.021224       0.009207
# attendance_percentage                    0.040479      -0.002092
# sleep_hours                              0.018236      -0.000935
# diet_quality                             0.026084       0.002406
# exercise_frequency                      -0.037319      -0.006448
# parental_education_level                -0.016840      -0.020531
# internet_quality                         0.036805       0.039563
# mental_health_rating                     0.001496       0.008034
# extracurricular_participation           -0.018597      -0.005125
# exam_score                              -0.166733      -0.171779
# gender_Male                             -0.004995       0.000937
# gender_Other                             0.015609       0.046266
#
#                                part_time_job  attendance_percentage  \
# age                                -0.011680              -0.026055
# study_hours_per_day                -0.029133               0.026264
# social_media_hours                  0.021224               0.040479
# netflix_hours                       0.009207              -0.002092
# part_time_job                       1.000000              -0.041771
# attendance_percentage              -0.041771               1.000000
# sleep_hours                         0.001645               0.013756
# diet_quality                        0.033785              -0.061024
# exercise_frequency                 -0.021679              -0.007857
# parental_education_level           -0.034099              -0.029672
# internet_quality                    0.009130              -0.039903
# mental_health_rating                0.013539              -0.018745
# extracurricular_participation      -0.022841              -0.017778
# exam_score                         -0.026608               0.089836
# gender_Male                         0.031409              -0.024108
# gender_Other                        0.011771              -0.001184
#
#                                sleep_hours  diet_quality  exercise_frequency  \
# age                               0.037482     -0.002006           -0.003836
# study_hours_per_day              -0.027757     -0.003565           -0.028701
# social_media_hours                0.018236      0.026084           -0.037319
# netflix_hours                    -0.000935      0.002406           -0.006448
# part_time_job                     0.001645      0.033785           -0.021679
# attendance_percentage             0.013756     -0.061024           -0.007857
# sleep_hours                       1.000000     -0.024224            0.019769
# diet_quality                     -0.024224      1.000000            0.024576
# exercise_frequency                0.019769      0.024576            1.000000
# parental_education_level          0.017303     -0.027720           -0.041687
# internet_quality                  0.002045      0.026316           -0.034657
# mental_health_rating             -0.006508      0.056837           -0.000242
# extracurricular_participation     0.027693      0.003525           -0.005681
# exam_score                        0.121683     -0.010857            0.160107
# gender_Male                      -0.024235      0.019382            0.068207
# gender_Other                      0.057166     -0.019288           -0.009269
#
#                                parental_education_level  internet_quality  \
# age                                            0.027578          0.007799
# study_hours_per_day                            0.001925          0.014459
# social_media_hours                            -0.016840          0.036805
# netflix_hours                                 -0.020531          0.039563
# part_time_job                                 -0.034099          0.009130
# attendance_percentage                         -0.029672         -0.039903
# sleep_hours                                    0.017303          0.002045
# diet_quality                                  -0.027720          0.026316
# exercise_frequency                            -0.041687         -0.034657
# parental_education_level                       1.000000          0.044919
# internet_quality                               0.044919          1.000000
# mental_health_rating                          -0.052828         -0.048283
# extracurricular_participation                 -0.004652         -0.031420
# exam_score                                    -0.021093         -0.036298
# gender_Male                                   -0.012097         -0.060479
# gender_Other                                  -0.038579          0.027655
#
#                                mental_health_rating  \
# age                                       -0.045101
# study_hours_per_day                       -0.003768
# social_media_hours                         0.001496
# netflix_hours                              0.008034
# part_time_job                              0.013539
# attendance_percentage                     -0.018745
# sleep_hours                               -0.006508
# diet_quality                               0.056837
# exercise_frequency                        -0.000242
# parental_education_level                  -0.052828
# internet_quality                          -0.048283
# mental_health_rating                       1.000000
# extracurricular_participation             -0.004741
# exam_score                                 0.321523
# gender_Male                               -0.006279
# gender_Other                               0.002810
#
#                                extracurricular_participation  exam_score  \
# age                                                -0.004993   -0.008907
# study_hours_per_day                                -0.003264    0.825419
# social_media_hours                                 -0.018597   -0.166733
# netflix_hours                                      -0.005125   -0.171779
# part_time_job                                      -0.022841   -0.026608
# attendance_percentage                              -0.017778    0.089836
# sleep_hours                                         0.027693    0.121683
# diet_quality                                        0.003525   -0.010857
# exercise_frequency                                 -0.005681    0.160107
# parental_education_level                           -0.004652   -0.021093
# internet_quality                                   -0.031420   -0.036298
# mental_health_rating                               -0.004741    0.321523
# extracurricular_participation                       1.000000    0.000881
# exam_score                                          0.000881    1.000000
# gender_Male                                        -0.007248   -0.013191
# gender_Other                                        0.006894    0.012976
#
#                                gender_Male  gender_Other
# age                               0.025562      0.015309
# study_hours_per_day              -0.025634      0.008814
# social_media_hours               -0.004995      0.015609
# netflix_hours                     0.000937      0.046266
# part_time_job                     0.031409      0.011771
# attendance_percentage            -0.024108     -0.001184
# sleep_hours                      -0.024235      0.057166
# diet_quality                      0.019382     -0.019288
# exercise_frequency                0.068207     -0.009269
# parental_education_level         -0.012097     -0.038579
# internet_quality                 -0.060479      0.027655
# mental_health_rating             -0.006279      0.002810
# extracurricular_participation    -0.007248      0.006894
# exam_score                       -0.013191      0.012976
# gender_Male                       1.000000     -0.199963
# gender_Other                     -0.199963      1.000000

# %%
correlation["parental_education_level"]
# Out:
# age                              0.027578
# study_hours_per_day              0.001925
# social_media_hours              -0.016840
# netflix_hours                   -0.020531
# part_time_job                   -0.034099
# attendance_percentage           -0.029672
# sleep_hours                      0.017303
# diet_quality                    -0.027720
# exercise_frequency              -0.041687
# parental_education_level         1.000000
# internet_quality                 0.044919
# mental_health_rating            -0.052828
# extracurricular_participation   -0.004652
# exam_score                      -0.021093
# gender_Male                     -0.012097
# gender_Other                    -0.038579
# Name: parental_education_level, dtype: float64

# %%
# d'après l'annalyse , il n'y a pas de corrélation avec les autres colonnes 
#donc nous allons remplacer les valeurs manquantes par le mode

print("d'après l'annalyse , il n'y a pas de corrélation avec les autres colonnes donc nous allons remplacer les valeurs manquantes par le mode")
# Out:
# d'après l'annalyse , il n'y a pas de corrélation avec les autres colonnes donc nous allons remplacer les valeurs manquantes par le mode

# %%
# remplaçons nos valeurs manquantes par le mode
data["parental_education_level"]=data["parental_education_level"].fillna(data["parental_education_level"].mode()[0])

# %%
# vérifions si nos valeurs manquantes ont été bien remplacé:
data.isnull().sum()
# Out:
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
# vérifions si nous avons des valeurs abérrantes dans notre dataset
data.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# min                56.000000     3.200000            0.000000
# 25%                78.000000     5.600000            1.000000
# 50%                84.400000     6.500000            3.000000
# 75%                91.025000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating   exam_score
# count           1000.000000  1000.000000
# mean               5.438000    69.601500
# std                2.847501    16.888564
# min                1.000000    18.400000
# 25%                3.000000    58.475000
# 50%                5.000000    70.500000
# 75%                8.000000    81.325000
# max               10.000000   100.000000

# %%
# encodage des variables catégorielles nominales
data=pd.get_dummies(data,columns=["gender"],drop_first=True)
data["part_time_job"]=(data["part_time_job"]=="Yes").astype(int)
data["extracurricular_participation"]=(data["extracurricular_participation"]=="Yes").astype(int)

# %%
#encodage des valeurs catégorielle ordinales
diet_map={"Poor": 1,"Fair":1, "Good":2}
p_map={"High School": 1,"Bachelor":2, "Master":3}
internet_map={"Poor": 1,"Average":2, "Good":3}

data["parental_education_level"]=data["parental_education_level"].map(p_map)
data["internet_quality"]=data["internet_quality"].map(internet_map)
data["diet_quality"]=data["diet_quality"].map(diet_map)

# %%
# séparation en features et variables cibles
X=data.drop(columns=["exam_score"])
Y=data["exam_score"].values

# %%
# fonction de normalisation
def normalisation(X):
    X_moy=X.mean(axis=0)
    X_std=X.std(axis=0)
    return (X-X_moy)/X_std

# %%
#sépartion pour l'entrainement
np.random.seed(42)
indices=np.random.permutation(len(X))

split=int(0.8*len(X))
train_idx=indices[:split]
test_idx=indices[split:]

x_train,x_test=X.iloc[train_idx],X.iloc[test_idx]
y_train,y_test=Y[train_idx],Y[test_idx]

# %%
#biais

def biais(x):
    m=x.shape[0]
    return np.hstack([np.ones((m,1)),x])


#fonction de prédiction

def prediction(x,w):
    return x@w


#fonction de calcul de l'erreur quadratique moyen mse

def mse(y,y_pred):
    m=len(y)
    return (np.sum((y-y_pred)**2))/m


#calcul du gradient

def gradient (x,y,y_pred):
    taille=len(y)
    residus=y-y_pred
    grad=-(2/taille)*(x.T@residus)

    return grad


#déscente du gradient

def desc_gradient(x,y,pas=0.05,iteration=1000):
    w=np.zeros(x.shape[1])
    tab_cout=[]

    for i in range(iteration):
        y_pred=prediction(x,w)
        grad=gradient(x,y,y_pred)
        cout=mse(y,y_pred)
        tab_cout.append(cout)
        w=w-pas*grad

    return w,tab_cout

# %%
# normalisation (sans biais)
x_train_n= normalisation(x_train)
x_test_n  = normalisation(x_test)

# ajout du biais
x_train_b = biais(x_train_n)
x_test_b  = biais(x_test_n)

# entraînement
w, tab_cout = desc_gradient(x_train_b, y_train, pas=0.01, iteration=1000)

# évaluation train
y_pred_train = prediction(x_train_b, w)
mse_train    = mse(y_train, y_pred_train)
ss_res_train = np.sum((y_train - y_pred_train)**2)
ss_tot_train = np.sum((y_train - y_train.mean())**2)
R2_train     = 1 - ss_res_train/ss_tot_train

# évaluation test
y_pred_test = prediction(x_test_b, w)
mse_test    = mse(y_test, y_pred_test)
ss_res_test = np.sum((y_test - y_pred_test)**2)
ss_tot_test = np.sum((y_test - y_test.mean())**2)
R2_test     = 1 - ss_res_test/ss_tot_test

print(f"entrainement --> mse={mse_train:.4f} | R2={R2_train:.4f}")
print(f"test         --> mse={mse_test:.4f} | R2={R2_test:.4f}")
# Out:
# entrainement --> mse=26.4757 | R2=0.9083
# test         --> mse=38.6413 | R2=0.8557

# %%
def polynome(X):
    X_carre = X**2
    return np.hstack([X, X_carre])

# normalisation avant polynome
x_train_n = normalisation(x_train)
x_test_n  = normalisation(x_test)

# features polynomiales
x_train_poly = polynome(x_train_n)
x_test_poly  = polynome(x_test_n)

# vérification
print(x_train.shape)
print(x_train_poly.shape)
print(x_test_poly.shape)

# biais
x_train_poly_b = biais(x_train_poly)
x_test_poly_b  = biais(x_test_poly)

# entraînement
w_poly, tab_cout_poly = desc_gradient(x_train_poly_b, y_train, pas=0.002, iteration=5000)

# évaluation train
y_pred_train_poly = prediction(x_train_poly_b, w_poly)
mse_train_poly    = mse(y_train, y_pred_train_poly)
R2_train_poly     = 1 - np.sum((y_train - y_pred_train_poly)**2) / np.sum((y_train - y_train.mean())**2)

# évaluation test
y_pred_test_poly = prediction(x_test_poly_b, w_poly)
mse_test_poly    = mse(y_test, y_pred_test_poly)
R2_test_poly     = 1 - np.sum((y_test - y_pred_test_poly)**2) / np.sum((y_test - y_test.mean())**2)

# évolution du coût
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(tab_cout, color='steelblue')
plt.title("Coût - Régression linéaire")
plt.xlabel("Itérations")
plt.ylabel("MSE")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(tab_cout_poly, color='darkorange')
plt.title("Coût - Régression polynomiale")
plt.xlabel("Itérations")
plt.ylabel("MSE")
plt.grid(True)

plt.tight_layout()
plt.show()

# comparaison
print("========== COMPARAISON ==========")
print(f"Linéaire   --> MSE train={mse_train:.4f} | R2 train={R2_train:.4f}")
print(f"Linéaire   --> MSE test ={mse_test:.4f}  | R2 test ={R2_test:.4f}")
print()
print(f"Polynomial --> MSE train={mse_train_poly:.4f} | R2 train={R2_train_poly:.4f}")
print(f"Polynomial --> MSE test ={mse_test_poly:.4f}  | R2 test ={R2_test_poly:.4f}")
# Out:
# (800, 15)
# (800, 30)
# (200, 30)
# ========== COMPARAISON ==========
# Linéaire   --> MSE train=26.4757 | R2 train=0.9083
# Linéaire   --> MSE test =38.6413  | R2 test =0.8557
#
# Polynomial --> MSE train=25.5359 | R2 train=0.9116
# Polynomial --> MSE test =39.3153  | R2 test =0.8532
